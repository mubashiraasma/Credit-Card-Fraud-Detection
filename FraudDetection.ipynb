# %% [markdown]
# ## Credit Card Fraud Detection

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.metrics import classification_report, confusion_matrix
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler
from imblearn.over_sampling import SMOTE
from sklearn.linear_model import LogisticRegression
from sklearn.naive_bayes import GaussianNB
from sklearn.ensemble import RandomForestClassifier

# %% [markdown]
# ### Data Loading

# %%
df = pd.read_csv("creditcard.csv")
df.head()
# Out:
#    Time        V1        V2        V3        V4        V5        V6        V7  \
# 0   0.0 -1.359807 -0.072781  2.536347  1.378155 -0.338321  0.462388  0.239599
# 1   0.0  1.191857  0.266151  0.166480  0.448154  0.060018 -0.082361 -0.078803
# 2   1.0 -1.358354 -1.340163  1.773209  0.379780 -0.503198  1.800499  0.791461
# 3   1.0 -0.966272 -0.185226  1.792993 -0.863291 -0.010309  1.247203  0.237609
# 4   2.0 -1.158233  0.877737  1.548718  0.403034 -0.407193  0.095921  0.592941
#
#          V8        V9  ...       V21       V22       V23       V24       V25  \
# 0  0.098698  0.363787  ... -0.018307  0.277838 -0.110474  0.066928  0.128539
# 1  0.085102 -0.255425  ... -0.225775 -0.638672  0.101288 -0.339846  0.167170
# 2  0.247676 -1.514654  ...  0.247998  0.771679  0.909412 -0.689281 -0.327642
# 3  0.377436 -1.387024  ... -0.108300  0.005274 -0.190321 -1.175575  0.647376
# 4 -0.270533  0.817739  ... -0.009431  0.798278 -0.137458  0.141267 -0.206010
#
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 284807 entries, 0 to 284806
# Data columns (total 31 columns):
#  #   Column  Non-Null Count   Dtype
# ---  ------  --------------   -----
#  0   Time    284807 non-null  float64
#  1   V1      284807 non-null  float64
#  2   V2      284807 non-null  float64
#  3   V3      284807 non-null  float64
#  4   V4      284807 non-null  float64
#  5   V5      284807 non-null  float64
#  6   V6      284807 non-null  float64
#  7   V7      284807 non-null  float64
#  8   V8      284807 non-null  float64
#  9   V9      284807 non-null  float64
#  10  V10     284807 non-null  float64
#  11  V11     284807 non-null  float64
#  12  V12     284807 non-null  float64
#  13  V13     284807 non-null  float64
#  14  V14     284807 non-null  float64
#  15  V15     284807 non-null  float64
#  16  V16     284807 non-null  float64
#  17  V17     284807 non-null  float64
#  18  V18     284807 non-null  float64
#  19  V19     284807 non-null  float64
# ...

# %%
df.isnull().sum()
# Out:
# Time      0
# V1        0
# V2        0
# V3        0
# V4        0
# V5        0
# V6        0
# V7        0
# V8        0
# V9        0
# V10       0
# V11       0
# V12       0
# V13       0
# V14       0
# V15       0
# V16       0
# V17       0
# V18       0
# V19       0
# V20       0
# V21       0
# V22       0
# V23       0
# V24       0
# V25       0
# V26       0
# V27       0
# V28       0
# Amount    0
# Class     0
# dtype: int64

# %%
df.duplicated()
# Out:
# 0         False
# 1         False
# 2         False
# 3         False
# 4         False
#           ...
# 284802    False
# 284803    False
# 284804    False
# 284805    False
# 284806    False
# Length: 284807, dtype: bool

# %%
df.describe()
# Out:
#                 Time            V1            V2            V3            V4  \
# count  284807.000000  2.848070e+05  2.848070e+05  2.848070e+05  2.848070e+05
# mean    94813.859575  1.168375e-15  3.416908e-16 -1.379537e-15  2.074095e-15
# std     47488.145955  1.958696e+00  1.651309e+00  1.516255e+00  1.415869e+00
# min         0.000000 -5.640751e+01 -7.271573e+01 -4.832559e+01 -5.683171e+00
# 25%     54201.500000 -9.203734e-01 -5.985499e-01 -8.903648e-01 -8.486401e-01
# 50%     84692.000000  1.810880e-02  6.548556e-02  1.798463e-01 -1.984653e-02
# 75%    139320.500000  1.315642e+00  8.037239e-01  1.027196e+00  7.433413e-01
# max    172792.000000  2.454930e+00  2.205773e+01  9.382558e+00  1.687534e+01
#
#                  V5            V6            V7            V8            V9  \
# count  2.848070e+05  2.848070e+05  2.848070e+05  2.848070e+05  2.848070e+05
# mean   9.604066e-16  1.487313e-15 -5.556467e-16  1.213481e-16 -2.406331e-15
# ...

# %%
class_distribution = df['Class'].value_counts()
class_distribution
# Out:
# Class
# 0    284315
# 1       492
# Name: count, dtype: int64

# %%
labels = ["Non-Fraud", "Fraud"]
plt.pie(class_distribution,labels=labels,autopct='%1.2f%%', startangle=30)
plt.title("Class Distribution")
plt.show()

# %%
corr_matrix = df.corr()

plt.figure(figsize=(20,10))
sns.heatmap(corr_matrix, cmap='coolwarm', annot=True, fmt='.2f')
plt.title('Correlation Matrix')
plt.show()

# %%
X = df.drop('Class',axis=1)
y = df['Class']

# %%
X.head()
# Out:
#    Time        V1        V2        V3        V4        V5        V6        V7  \
# 0   0.0 -1.359807 -0.072781  2.536347  1.378155 -0.338321  0.462388  0.239599
# 1   0.0  1.191857  0.266151  0.166480  0.448154  0.060018 -0.082361 -0.078803
# 2   1.0 -1.358354 -1.340163  1.773209  0.379780 -0.503198  1.800499  0.791461
# 3   1.0 -0.966272 -0.185226  1.792993 -0.863291 -0.010309  1.247203  0.237609
# 4   2.0 -1.158233  0.877737  1.548718  0.403034 -0.407193  0.095921  0.592941
#
#          V8        V9  ...       V20       V21       V22       V23       V24  \
# 0  0.098698  0.363787  ...  0.251412 -0.018307  0.277838 -0.110474  0.066928
# 1  0.085102 -0.255425  ... -0.069083 -0.225775 -0.638672  0.101288 -0.339846
# 2  0.247676 -1.514654  ...  0.524980  0.247998  0.771679  0.909412 -0.689281
# 3  0.377436 -1.387024  ... -0.208038 -0.108300  0.005274 -0.190321 -1.175575
# 4 -0.270533  0.817739  ...  0.408542 -0.009431  0.798278 -0.137458  0.141267
#
# ...

# %% [markdown]
# ### Scaling of numerical Features

# %%
scaler = StandardScaler()
X_scaled = scaler.fit_transform(X)
X_scaled = pd.DataFrame(X_scaled, columns=X.columns)

# %% [markdown]
# #### Splitting the dataset using stratified sampling

# %%
X_train, X_test, y_train, y_test = train_test_split(X_scaled, y, test_size=0.2, random_state=42, stratify=y)

# %% [markdown]
# #### Applying SMOTE

# %%
smote = SMOTE(random_state=42)
X_train_smote, y_train_smote = smote.fit_resample(X_train, y_train)

# %% [markdown]
# ### Creating Models

# %% [markdown]
# #### Logistic Regression

# %%
lr = LogisticRegression()

# %%
lr_model = lr.fit(X_train_smote, y_train_smote)
y_predict = lr_model.predict(X_test)
print(classification_report(y_predict, y_test))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.97      1.00      0.99     55410
#            1       0.92      0.06      0.11      1552
#
#     accuracy                           0.97     56962
#    macro avg       0.95      0.53      0.55     56962
# weighted avg       0.97      0.97      0.96     56962

# %%
# Confusion matrix
conf_matrix_lr = confusion_matrix(y_test, y_predict)
sns.heatmap(conf_matrix_lr, annot=True, fmt='d', xticklabels=labels, yticklabels=labels)
plt.xlabel('Predicted')
plt.ylabel('Actual')
plt.title('Logistic Regression - Confusion Matrix')
plt.show()

# %% [markdown]
# #### Naive Bayes

# %%
naive = GaussianNB()
naive_model = naive.fit(X_train_smote,y_train_smote)
y_predict_naive = naive_model.predict(X_test)
print(classification_report(y_predict_naive, y_test))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.97      1.00      0.99     55430
#            1       0.88      0.06      0.11      1532
#
#     accuracy                           0.97     56962
#    macro avg       0.93      0.53      0.55     56962
# weighted avg       0.97      0.97      0.96     56962

# %%
# Confusion matrix
conf_matrix_naive = confusion_matrix(y_test, y_predict_naive)
sns.heatmap(conf_matrix_naive, annot=True, fmt='d', xticklabels=labels, yticklabels=labels)
plt.xlabel('Predicted')
plt.ylabel('Actual')
plt.title('Naive Bayes - Confusion Matrix')
plt.show()

# %% [markdown]
# #### Random Forest Classifier

# %%
rfc = RandomForestClassifier(class_weight='balanced', random_state=42)
rfc_model = rfc.fit(X_train_smote, y_train_smote)

# %%
y_predict_rfc = rfc_model.predict(X_test)
print(classification_report(y_predict_rfc, y_test))
# Out:
#               precision    recall  f1-score   support
#
#            0       1.00      1.00      1.00     56869
#            1       0.83      0.87      0.85        93
#
#     accuracy                           1.00     56962
#    macro avg       0.91      0.94      0.92     56962
# weighted avg       1.00      1.00      1.00     56962

# %%
confusionMatrix = confusion_matrix(y_predict_rfc, y_test)
sns.heatmap(confusionMatrix, annot=True, fmt='d',
            xticklabels=['Non-Fraud', 'Fraud'], 
            yticklabels=['Non-Fraud', 'Fraud'])
plt.xlabel('Predicted')
plt.ylabel('Actual')
plt.title('Confusion Matrix')
plt.show()

# %% [markdown]
# #### XGBoost

# %%
from xgboost import XGBClassifier
from sklearn.metrics import classification_report, confusion_matrix

# Initialize the model
xgb = XGBClassifier(scale_pos_weight=class_distribution[0] / class_distribution[1], random_state=42)

# Train the model
xgb_model = xgb.fit(X_train_smote, y_train_smote)

# Predict on test data
y_predict_xgb = xgb_model.predict(X_test)

# Classification report
print("Classification Report for XGBoost Classifier:")
print(classification_report(y_test, y_predict_xgb))
# Out:
# Classification Report for XGBoost Classifier:
#               precision    recall  f1-score   support
#
#            0       1.00      1.00      1.00     56864
#            1       0.50      0.88      0.63        98
#
#     accuracy                           1.00     56962
#    macro avg       0.75      0.94      0.82     56962
# weighted avg       1.00      1.00      1.00     56962

# %%
# Confusion matrix
conf_matrix_xgb = confusion_matrix(y_test, y_predict_xgb)
sns.heatmap(conf_matrix_xgb, annot=True, fmt='d', xticklabels=labels, yticklabels=labels)
plt.xlabel('Predicted')
plt.ylabel('Actual')
plt.title('XGBoost Classifier - Confusion Matrix')
plt.show()

# %%
from sklearn.svm import SVC
from sklearn.metrics import classification_report, confusion_matrix

# Initialize the model
svm = SVC(class_weight='balanced', random_state=42)

# Train the model
svm_model = svm.fit(X_train_smote, y_train_smote)

# Predict on test data
y_predict_svm = svm_model.predict(X_test)

# Classification report
print("Classification Report for Support Vector Machine (SVM):")
print(classification_report(y_test, y_predict_svm))

# Confusion matrix
conf_matrix_svm = confusion_matrix(y_test, y_predict_svm)
sns.heatmap(conf_matrix_svm, annot=True, fmt='d', xticklabels=labels, yticklabels=labels)
plt.xlabel('Predicted')
plt.ylabel('Actual')
plt.title('Support Vector Machine - Confusion Matrix')
plt.show()
# Out:
# Classification Report for Support Vector Machine (SVM):
#               precision    recall  f1-score   support
#
#            0       1.00      0.98      0.99     56864
#            1       0.09      0.87      0.16        98
#
#     accuracy                           0.98     56962
#    macro avg       0.54      0.93      0.57     56962
# weighted avg       1.00      0.98      0.99     56962
